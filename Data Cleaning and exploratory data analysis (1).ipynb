# %%
#importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os
os.path.exists(r"C:\Users\jarup\Downloads\laptops_test.csv")
# Out:
# True

# %%
import os
os.path.exists(r"C:\Users\jarup\Downloads\laptops_train.csv")
# Out:
# True

# %%
df_train=pd.read_csv(r"C:\Users\jarup\Downloads\laptops_train.csv")
df_test=pd.read_csv(r"C:\Users\jarup\Downloads\laptops_test.csv")

# %%
df_train
# Out:
#     Manufacturer       Model Name   Category Screen Size  \
# 0          Apple      MacBook Pro  Ultrabook       13.3"
# 1          Apple      Macbook Air  Ultrabook       13.3"
# 2             HP           250 G6   Notebook       15.6"
# 3          Apple      MacBook Pro  Ultrabook       15.4"
# 4          Apple      MacBook Pro  Ultrabook       13.3"
# ..           ...              ...        ...         ...
# 972         Dell     Alienware 17     Gaming       17.3"
# 973      Toshiba  Tecra A40-C-1DF   Notebook       14.0"
# 974         Asus        Rog Strix     Gaming       17.3"
# 975           HP      Probook 450   Notebook       15.6"
# 976       Lenovo    ThinkPad T460   Notebook       14.0"
#
#                                  Screen                          CPU   RAM  \
# 0    IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz   8GB
# 1                              1440x900         Intel Core i5 1.8GHz   8GB
# ...

# %%
df_train.shape,df_test.shape
# Out:
# ((977, 13), (325, 13))

# %%
df_train.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# ...

# %%
df_test.head()
# Out:
#   Manufacturer                         Model Name            Category  \
# 0           HP  15-bs053od (i7-7500U/6GB/1TB/W10)            Notebook
# 1         Asus                   Rog GL753VE-DS74              Gaming
# 2         Dell                      Inspiron 7579  2 in 1 Convertible
# 3      Toshiba                  Portege Z30-C-1CV            Notebook
# 4       Lenovo                  IdeaPad 320-15ABR            Notebook
#
#   Screen Size                                     Screen  \
# 0       15.6"                                   1366x768
# 1       17.3"                          Full HD 1920x1080
# 2       15.6"  IPS Panel Full HD / Touchscreen 1920x1080
# 3       13.3"                          Full HD 1920x1080
# 4       15.6"                          Full HD 1920x1080
#
#                            CPU   RAM               Storage  \
# 0   Intel Core i7 7500U 2.7GHz   6GB               1TB HDD
# 1  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# ...

# %%
#Merging data sets

# %%
df=pd.concat([df_train,df_test],axis=0,ignore_index=True)

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# ...

# %%
df.shape
# Out:
# (1302, 13)

# %%
#Exploratory data analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1302 entries, 0 to 1301
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              1302 non-null   object
#  1   Model Name                1302 non-null   object
#  2   Category                  1302 non-null   object
#  3   Screen Size               1302 non-null   object
#  4   Screen                    1302 non-null   object
#  5   CPU                       1302 non-null   object
#  6   RAM                       1302 non-null   object
#  7    Storage                  1302 non-null   object
#  8   GPU                       1302 non-null   object
#  9   Operating System          1302 non-null   object
#  10  Operating System Version  1132 non-null   object
#  11  Weight                    1302 non-null   object
#  12  Price                     1302 non-null   float64
# dtypes: float64(1), object(12)
# ...

# %%
df.isnull().sum()
# Out:
# Manufacturer                  0
# Model Name                    0
# Category                      0
# Screen Size                   0
# Screen                        0
# CPU                           0
# RAM                           0
#  Storage                      0
# GPU                           0
# Operating System              0
# Operating System Version    170
# Weight                        0
# Price                         0
# dtype: int64

# %%
#Conclusion : There are 170 Null Values in operating system version

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\jarup\AppData\Local\Temp\ipykernel_9440\834922981.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %% [raw]
# #price column is not normally distributed

# %%
df['Operating System Version'].value_counts()
# Out:
# Operating System Version
# 10      1071
# 7         45
# X          8
# 10 S       8
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,5))
df['Operating System Version'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Operating System Version'>

# %%
#windows 10 osv is used in maximum laptops

# %%
#operating system vs operating system version
df[df['Operating System Version'].isnull()]['Operating System'].value_counts()
# Out:
# Operating System
# No OS        66
# Linux        62
# Chrome OS    27
# macOS        13
# Android       2
# Name: count, dtype: int64

# %%
#noticed that n NO OS,Linux,Android and chrome OS Every data value we have is null

# %%
df.duplicated().sum()
# Out:
# 28

# %%
##droping duplicate values
df.shape
# Out:
# (1302, 13)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1274, 13)

# %%
df['Operating System Version'].unique()
# Out:
# array([nan, '10', 'X', '10 S', '7'], dtype=object)

# %%
df['Operating System Version'].value_counts(dropna=False)
# Out:
# Operating System Version
# 10      1047
# NaN      166
# 7         45
# X          8
# 10 S       8
# Name: count, dtype: int64

# %%
#From the above info we conclude that there is not sufficient data for Operating System Version

# %%
df.drop('Operating System Version',axis=1,inplace=True)

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS  1.37kg
# ...

# %%
df['Price'].max()
# Out:
# 54232308.0

# %%
df[df['Price']==54232308.0]
# Out:
#     Manufacturer Model Name Category Screen Size  \
# 196        Razer  Blade Pro   Gaming       17.3"
#
#                                   Screen                          CPU   RAM  \
# 196  4K Ultra HD / Touchscreen 3840x2160  Intel Core i7 7820HK 2.9GHz  32GB
#
#      Storage                      GPU Operating System  Weight       Price
# 196  1TB SSD  Nvidia GeForce GTX 1080          Windows  3.49kg  54232308.0

# %%
df['Price'].min()
# Out:
# 1547208.0

# %%
df[df['Price']==1547208.0]
# Out:
#      Manufacturer                        Model Name Category Screen Size  \
# 1214         Acer  C740-C9QX (3205U/2GB/32GB/Chrome  Netbook       11.6"
#
#         Screen                                   CPU  RAM   Storage  \
# 1214  1366x768  Intel Celeron Dual Core 3205U 1.5GHz  2GB  32GB SSD
#
#                     GPU Operating System Weight      Price
# 1214  Intel HD Graphics        Chrome OS  1.3kg  1547208.0

# %%
#ACER is manufacturing the most cheapest Laptops

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS  1.37kg
# ...

# %%
df['Manufacturer'].unique()
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', 'Chuwi', 'MSI',
#        'Microsoft', 'Toshiba', 'Huawei', 'Xiaomi', 'Vero', 'Razer',
#        'Mediacom', 'Samsung', 'Google', 'Fujitsu', 'LG'], dtype=object)

# %%
for column in df.columns:
    unique_values = df[column].unique()
    print(f"Unique values in {column}: {unique_values}")
# Out:
# Unique values in Manufacturer: ['Apple' 'HP' 'Acer' 'Asus' 'Dell' 'Lenovo' 'Chuwi' 'MSI' 'Microsoft'
#  'Toshiba' 'Huawei' 'Xiaomi' 'Vero' 'Razer' 'Mediacom' 'Samsung' 'Google'
#  'Fujitsu' 'LG']
# Unique values in Model Name: ['MacBook Pro' 'Macbook Air' '250 G6' 'Aspire 3' 'ZenBook UX430UN'
#  'Swift 3' 'Inspiron 3567' 'MacBook 12"' 'IdeaPad 320-15IKB' 'XPS 13'
#  'Vivobook E200HA' 'Legion Y520-15IKBN' '255 G6' 'Inspiron 5379'
#  '15-BS101nv (i7-8550U/8GB/256GB/FHD/W10)' 'MacBook Air' 'Inspiron 5570'
#  'Latitude 5590' 'ProBook 470' 'LapBook 15.6"'
#  'E402WA-GA010T (E2-6110/2GB/32GB/W10)'
#  '17-ak001nv (A6-9220/4GB/500GB/Radeon' 'IdeaPad 120S-14IAP'
#  'Inspiron 5770' 'ProBook 450' 'X540UA-DM186 (i3-6006U/4GB/1TB/FHD/Linux)'
#  'Inspiron 7577' 'X542UQ-GO005 (i5-7200U/8GB/1TB/GeForce'
#  'Aspire A515-51G' 'Inspiron 7773' 'IdeaPad 320-15ISK' 'Rog Strix'
#  'X751NV-TY001T (N4200/4GB/1TB/GeForce' 'Yoga Book' 'ProBook 430'
# ...

# %%
df['Category'].unique()
# Out:
# array(['Ultrabook', 'Notebook', 'Netbook', 'Gaming', '2 in 1 Convertible',
#        'Workstation'], dtype=object)

# %%
df['Category'].value_counts()
# Out:
# Category
# Notebook              707
# Gaming                205
# Ultrabook             194
# 2 in 1 Convertible    116
# Workstation            29
# Netbook                23
# Name: count, dtype: int64

# %%
df['Screen Size'].value_counts()
# Out:
# Screen Size
# 15.6"    646
# 14.0"    193
# 17.3"    164
# 13.3"    160
# 12.5"     39
# 11.6"     31
# 12.0"      6
# 13.5"      6
# 13.9"      6
# 12.3"      5
# 10.1"      4
# 15.4"      4
# 15.0"      4
# 13.0"      2
# 18.4"      1
# 17.0"      1
# 14.1"      1
# 11.3"      1
# Name: count, dtype: int64

# %%
df['Screen Size']=df['Screen Size'].str.replace(' "" ','')

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS  1.37kg
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      1274 non-null   object
#  1   Model Name        1274 non-null   object
#  2   Category          1274 non-null   object
#  3   Screen Size       1274 non-null   object
#  4   Screen            1274 non-null   object
#  5   CPU               1274 non-null   object
#  6   RAM               1274 non-null   object
#  7    Storage          1274 non-null   object
#  8   GPU               1274 non-null   object
#  9   Operating System  1274 non-null   object
#  10  Weight            1274 non-null   object
#  11  Price             1274 non-null   float64
# dtypes: float64(1), object(11)
# memory usage: 129.4+ KB

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS  1.37kg
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      1274 non-null   object
#  1   Model Name        1274 non-null   object
#  2   Category          1274 non-null   object
#  3   Screen Size       1274 non-null   object
#  4   Screen            1274 non-null   object
#  5   CPU               1274 non-null   object
#  6   RAM               1274 non-null   object
#  7    Storage          1274 non-null   object
#  8   GPU               1274 non-null   object
#  9   Operating System  1274 non-null   object
#  10  Weight            1274 non-null   object
#  11  Price             1274 non-null   float64
# dtypes: float64(1), object(11)
# memory usage: 129.4+ KB

# %%
df['Screen Size'] = pd.to_numeric(df['Screen Size'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      1274 non-null   object
#  1   Model Name        1274 non-null   object
#  2   Category          1274 non-null   object
#  3   Screen Size       0 non-null      float64
#  4   Screen            1274 non-null   object
#  5   CPU               1274 non-null   object
#  6   RAM               1274 non-null   object
#  7    Storage          1274 non-null   object
#  8   GPU               1274 non-null   object
#  9   Operating System  1274 non-null   object
#  10  Weight            1274 non-null   object
#  11  Price             1274 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 129.4+ KB

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook          NaN
# 1        Apple  Macbook Air  Ultrabook          NaN
# 2           HP       250 G6   Notebook          NaN
# 3        Apple  MacBook Pro  Ultrabook          NaN
# 4        Apple  MacBook Pro  Ultrabook          NaN
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS  1.37kg
# ...

# %%
df['Screen'].nunique()
# Out:
# 40

# %%
df['Screen'].value_counts()
# Out:
# Screen
# Full HD 1920x1080                                505
# 1366x768                                         263
# IPS Panel Full HD 1920x1080                      226
# IPS Panel Full HD / Touchscreen 1920x1080         51
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160                9
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# ...

# %%
df['Sreen Resolution']=df['Screen'].str.extract(r'(\d+x\d+)')

# %%
df['Display Type']=df['Screen'].str.replace(r'(\d+x\d+)','',regex=True)

# %%
df['Display Type']=df['Display Type'].str.replace(r'(HD|Full HD|Ultra HD|4k Ultra|\+|/)','',regex=True)

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook          NaN
# 1        Apple  Macbook Air  Ultrabook          NaN
# 2           HP       250 G6   Notebook          NaN
# 3        Apple  MacBook Pro  Ultrabook          NaN
# 4        Apple  MacBook Pro  Ultrabook          NaN
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS  1.37kg
# ...

# %%
df['Touchscreen']=df['Display Type'].str.extract(r'(Touchscreen)')
df['Display Type']=df['Display Type'].str.replace(r'(Touchscreen)','',regex=True)
df['Touchscreen']=df['Touchscreen'].replace('Touchscreen',1)
df['Touchscreen']=df['Touchscreen'].replace(np.nan,0)
# Out:
# C:\Users\jarup\AppData\Local\Temp\ipykernel_9440\2354817739.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Touchscreen']=df['Touchscreen'].replace('Touchscreen',1)

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook          NaN
# 1        Apple  Macbook Air  Ultrabook          NaN
# 2           HP       250 G6   Notebook          NaN
# 3        Apple  MacBook Pro  Ultrabook          NaN
# 4        Apple  MacBook Pro  Ultrabook          NaN
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS  1.37kg
# ...

# %%
#df.drop(df['Desplay Type'],inplace=True)

# %%
df.tail()
# Out:
#      Manufacturer                           Model Name            Category  \
# 1269       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1270       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1271       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1272           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1273         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#       Screen Size                                      Screen  \
# 1269          NaN   IPS Panel Full HD / Touchscreen 1920x1080
# 1270          NaN  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1271          NaN                                    1366x768
# 1272          NaN                                    1366x768
# 1273          NaN                                    1366x768
#
#                                        CPU   RAM             Storage  \
# ...

# %%
df['Display Type'].value_counts()
# Out:
# Display Type
#                              537
#                              296
# IPS Panel                    244
# IPS Panel                     51
#                               48
# IPS Panel Retina Display      17
# Quad                          15
# IPS Panel 4K                  12
# IPS Panel 4K                  11
# IPS Panel                     11
# 4K                             9
# 4K                             7
# IPS Panel Quad                 5
# IPS Panel Quad                 4
# Quad                           3
# IPS Panel   4K                 2
#   Quad                         1
#   4K                           1
# Name: count, dtype: int64

# %%
df['Display Type']=df['Display Type'].str.replace(r' ','',regex=True)

# %%
df['Display Type']=df['Display Type'].replace(r'^\s*$',np.nan,regex=True)

# %%
df['Display Type'].value_counts()
# Out:
# Display Type
# IPSPanel                 306
# IPSPanel4K                25
# Quad                      19
# IPSPanelRetinaDisplay     17
# 4K                        17
# IPSPanelQuad               9
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook          NaN
# 1        Apple  Macbook Air  Ultrabook          NaN
# 2           HP       250 G6   Notebook          NaN
# 3        Apple  MacBook Pro  Ultrabook          NaN
# 4        Apple  MacBook Pro  Ultrabook          NaN
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS  1.37kg
# ...

# %%
df['Touchscreen'].value_counts()
# Out:
# Touchscreen
# 0.0    1087
# 1.0     187
# Name: count, dtype: int64

# %%
df.drop('Screen',axis=1,inplace=True)

# %%
df.sample(10)
# Out:
#      Manufacturer                             Model Name            Category  \
# 101            HP  15-bw000nv (E2-9000e/4GB/500GB/Radeon            Notebook
# 335            HP                          EliteBook 840            Notebook
# 625        Lenovo                      IdeaPad 320-15IKB            Notebook
# 701        Lenovo                      IdeaPad 320-15AST            Notebook
# 578           MSI                           GT73VR Titan              Gaming
# 1151       Lenovo        B51-80 (i5-6200U/8GB/1TB/Radeon            Notebook
# 298        Lenovo                      IdeaPad 310-15ABR            Notebook
# 957            HP                           ProBook x360  2 in 1 Convertible
# 642        Lenovo                            ThinkPad X1           Ultrabook
# 312           MSI                             GE63VR 7RF              Gaming
#
#       Screen Size                                   CPU   RAM  \
# ...

# %%
df['Display Type'].value_counts(dropna=False)
# Out:
# Display Type
# NaN                      881
# IPSPanel                 306
# IPSPanel4K                25
# Quad                      19
# IPSPanelRetinaDisplay     17
# 4K                        17
# IPSPanelQuad               9
# Name: count, dtype: int64

# %%
# Extract the first word from the 'CPU' column and create a new column 'CPU_Manufacturer'
df['CPU_Manufacturer'] = df['CPU'].apply(lambda x: x.split()[0])

# %%
# Extract the first word from the 'GPU' column and create a new column 'GPU_Manufacturer'
df['GPU_Manufacturer'] = df['GPU'].apply(lambda x: x.split()[0])

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook          NaN
# 1        Apple  Macbook Air  Ultrabook          NaN
# 2           HP       250 G6   Notebook          NaN
# 3        Apple  MacBook Pro  Ultrabook          NaN
# 4        Apple  MacBook Pro  Ultrabook          NaN
#
#                           CPU   RAM              Storage  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             GPU Operating System  Weight        Price  \
# 0  Intel Iris Plus Graphics 640            macOS  1.37kg  11912523.48
# 1        Intel HD Graphics 6000            macOS  1.34kg   7993374.48
# 2         Intel HD Graphics 620            No OS  1.86kg   5112900.00
# ...

# %%
df['CPU_Manufacturer'].value_counts().plot(kind='bar',color='cyan')
# Out:
# <Axes: xlabel='CPU_Manufacturer'>

# %%
df['GPU_Manufacturer'].value_counts().plot(kind='bar',color='red')
# Out:
# <Axes: xlabel='GPU_Manufacturer'>

# %%
df['CPU'].unique()
# Out:
# array(['Intel Core i5 2.3GHz', 'Intel Core i5 1.8GHz',
#        'Intel Core i5 7200U 2.5GHz', 'Intel Core i7 2.7GHz',
#        'Intel Core i5 3.1GHz', 'AMD A9-Series 9420 3GHz',
#        'Intel Core i7 2.2GHz', 'Intel Core i7 8550U 1.8GHz',
#        'Intel Core i5 8250U 1.6GHz', 'Intel Core i3 6006U 2GHz',
#        'Intel Core i7 2.8GHz', 'Intel Core M m3 1.2GHz',
#        'Intel Core i7 7500U 2.7GHz', 'Intel Core i7 2.9GHz',
#        'Intel Core i3 7100U 2.4GHz', 'Intel Atom x5-Z8350 1.44GHz',
#        'Intel Core i5 7300HQ 2.5GHz', 'AMD E-Series E2-9000e 1.5GHz',
#        'Intel Core i5 1.6GHz', 'Intel Core i7 8650U 1.9GHz',
#        'Intel Atom x5-Z8300 1.44GHz', 'AMD E-Series E2-6110 1.5GHz',
#        'AMD A6-Series 9220 2.5GHz',
#        'Intel Celeron Dual Core N3350 1.1GHz',
#        'Intel Core i3 7130U 2.7GHz', 'Intel Core i7 7700HQ 2.8GHz',
#        'Intel Core i5 2.0GHz', 'AMD Ryzen 1700 3GHz',
#        'Intel Pentium Quad Core N4200 1.1GHz',
# ...

# %%
#Conclusion :intel is manufacturing the Maximum CPU ANd GPU

# %%
import re

# %%
def extract_frequency(cpu_string):
    match = re.search(r'\d+(\.\d+)?GHz', cpu_string)
    return match.group(0) if match else None

# Apply the function to create the new column
df['Frequency'] = df['CPU'].apply(extract_frequency)

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook          NaN
# 1        Apple  Macbook Air  Ultrabook          NaN
# 2           HP       250 G6   Notebook          NaN
# 3        Apple  MacBook Pro  Ultrabook          NaN
# 4        Apple  MacBook Pro  Ultrabook          NaN
#
#                           CPU   RAM              Storage  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             GPU Operating System  Weight        Price  \
# 0  Intel Iris Plus Graphics 640            macOS  1.37kg  11912523.48
# 1        Intel HD Graphics 6000            macOS  1.34kg   7993374.48
# 2         Intel HD Graphics 620            No OS  1.86kg   5112900.00
# ...

# %%
df.isnull().sum()
# Out:
# Manufacturer           0
# Model Name             0
# Category               0
# Screen Size         1274
# CPU                    0
# RAM                    0
#  Storage               0
# GPU                    0
# Operating System       0
# Weight                 0
# Price                  0
# Sreen Resolution       0
# Display Type         881
# Touchscreen            0
# CPU_Manufacturer       0
# GPU_Manufacturer       0
# Frequency              0
# dtype: int64

# %%
df[df['Frequency']=='2.5']['Manufacturer'].mode()
# Out:
# Series([], Name: Manufacturer, dtype: object)

# %%
#Lenovo is manufacturing the max 2.5GHz frequency laptops

# %%
df.head(2)
# Out:
#   Manufacturer   Model Name   Category  Screen Size                   CPU  \
# 0        Apple  MacBook Pro  Ultrabook          NaN  Intel Core i5 2.3GHz
# 1        Apple  Macbook Air  Ultrabook          NaN  Intel Core i5 1.8GHz
#
#    RAM              Storage                           GPU Operating System  \
# 0  8GB            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  8GB  128GB Flash Storage        Intel HD Graphics 6000            macOS
#
#    Weight        Price Sreen Resolution           Display Type  Touchscreen  \
# 0  1.37kg  11912523.48        2560x1600  IPSPanelRetinaDisplay          0.0
# 1  1.34kg   7993374.48         1440x900                    NaN          0.0
#
#   CPU_Manufacturer GPU_Manufacturer Frequency
# 0            Intel            Intel    2.3GHz
# 1            Intel            Intel    1.8GHz

# %%
df.isnull().sum()
# Out:
# Manufacturer           0
# Model Name             0
# Category               0
# Screen Size         1274
# CPU                    0
# RAM                    0
#  Storage               0
# GPU                    0
# Operating System       0
# Weight                 0
# Price                  0
# Sreen Resolution       0
# Display Type         881
# Touchscreen            0
# CPU_Manufacturer       0
# GPU_Manufacturer       0
# Frequency              0
# dtype: int64

# %%
df['Frequency'].dtype
# Out:
# dtype('O')

# %%
df['CPU']=df['CPU'].str.replace(r'(\d+(?:\.\d+)?GHz)','',regex=True)

# %%
df.head(2)
# Out:
#   Manufacturer   Model Name   Category  Screen Size             CPU  RAM  \
# 0        Apple  MacBook Pro  Ultrabook          NaN  Intel Core i5   8GB
# 1        Apple  Macbook Air  Ultrabook          NaN  Intel Core i5   8GB
#
#                Storage                           GPU Operating System  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS  1.34kg
#
#          Price Sreen Resolution           Display Type  Touchscreen  \
# 0  11912523.48        2560x1600  IPSPanelRetinaDisplay          0.0
# 1   7993374.48         1440x900                    NaN          0.0
#
#   CPU_Manufacturer GPU_Manufacturer Frequency
# 0            Intel            Intel    2.3GHz
# 1            Intel            Intel    1.8GHz

# %%
df.tail(2)
# Out:
#      Manufacturer                           Model Name  Category  Screen Size  \
# 1272           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon  Notebook          NaN
# 1273         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)  Notebook          NaN
#
#                                  CPU  RAM    Storage                 GPU  \
# 1272            Intel Core i7 6500U   6GB    1TB HDD  AMD Radeon R5 M330
# 1273  Intel Celeron Dual Core N3050   4GB  500GB HDD   Intel HD Graphics
#
#      Operating System  Weight      Price Sreen Resolution Display Type  \
# 1272          Windows  2.19kg  6793488.0         1366x768          NaN
# 1273          Windows   2.2kg  3281148.0         1366x768          NaN
#
#       Touchscreen CPU_Manufacturer GPU_Manufacturer Frequency
# 1272          0.0            Intel              AMD    2.5GHz
# 1273          0.0            Intel            Intel    1.6GHz

# %%
df['RAM'].unique()
# Out:
# array(['8GB', '16GB', '4GB', '2GB', '12GB', '6GB', '32GB', '24GB', '64GB'],
#       dtype=object)

# %%
df['RAM'].value_counts().plot(kind='bar',color='brown',xlabel='RAM',title='RAM Count')
# Out:
# <Axes: title={'center': 'RAM Count'}, xlabel='RAM'>

# %%
#conculsion : Laptops are mostly manufactured in 8GB RAM

# %%
df['RAM(in GB)'] = df['RAM'].str.replace('GB', '')

# %%
df.drop('RAM',axis=1,inplace=True)

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size                   CPU  \
# 0        Apple  MacBook Pro  Ultrabook          NaN        Intel Core i5
# 1        Apple  Macbook Air  Ultrabook          NaN        Intel Core i5
# 2           HP       250 G6   Notebook          NaN  Intel Core i5 7200U
# 3        Apple  MacBook Pro  Ultrabook          NaN        Intel Core i7
# 4        Apple  MacBook Pro  Ultrabook          NaN        Intel Core i5
#
#                Storage                           GPU Operating System  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620            No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455            macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650            macOS  1.37kg
#
# ...

# %%
df['RAM(in GB)']=df['RAM(in GB)'].astype(float)

# %%
df['Touchscreen']=df['Touchscreen'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      1274 non-null   object
#  1   Model Name        1274 non-null   object
#  2   Category          1274 non-null   object
#  3   Screen Size       0 non-null      float64
#  4   CPU               1274 non-null   object
#  5    Storage          1274 non-null   object
#  6   GPU               1274 non-null   object
#  7   Operating System  1274 non-null   object
#  8   Weight            1274 non-null   object
#  9   Price             1274 non-null   float64
#  10  Sreen Resolution  1274 non-null   object
#  11  Display Type      393 non-null    object
#  12  Touchscreen       1274 non-null   int32
#  13  CPU_Manufacturer  1274 non-null   object
#  14  GPU_Manufacturer  1274 non-null   object
#  15  Frequency         1274 non-null   object
# ...

# %%
df['Weight(in Kg)'] = df['Weight'].str.replace('kg', '')

# %%
df.drop('Weight',axis=1,inplace=True)

# %%
df['Weight(in Kg)']=df['Weight(in Kg)'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[229], line 1
# ----> 1 df['Weight(in Kg)']=df['Weight(in Kg)'].astype(float)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
# ...

# %%
df['Weight(in Kg)']=df['Weight(in Kg)'].replace('4s',4.0)

# %%
df['Weight(in Kg)'].unique()
# Out:
# array(['1.37', '1.34', '1.86', '1.83', '2.1', '2.04', '1.3', '1.6', '2.2',
#        '0.92', '1.22', '0.98', '2.5', '1.62', '1.91', '2.3', '1.35',
#        '1.88', '1.89', '1.65', '2.71', '1.2', '1.44', '2.8', '2', '2.65',
#        '2.77', '3.2', '0.69', '1.49', '2.4', '2.13', '2.43', '1.7', '1.4',
#        '1.8', '1.9', '3', '1.252', '2.7', '2.02', '1.63', '1.96', '1.21',
#        '2.45', '1.25', '1.5', '2.62', '1.38', '1.58', '1.85', '1.23',
#        '1.26', '2.16', '2.36', '2.05', '1.32', '1.75', '0.97', '2.9',
#        '2.56', '1.48', '1.74', '1.1', '1.56', '2.03', '1.05', '4.4',
#        '1.90', '1.29', '2.0', '1.95', '2.06', '1.12', '1.42', '3.49',
#        '3.35', '2.23', '4.42', '2.69', '2.37', '4.7', '3.6', '2.08',
#        '4.3', '1.68', '1.41', '4.14', '2.18', '2.24', '2.67', '2.14',
#        '1.36', '2.25', '2.15', '2.19', '2.54', '3.42', '1.28', '2.33',
#        '1.45', '2.79', '1.84', '2.6', '2.26', '3.25', '1.59', '1.13',
# ...

# %%
df['Weight(in Kg)']=df['Weight(in Kg)'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      1274 non-null   object
#  1   Model Name        1274 non-null   object
#  2   Category          1274 non-null   object
#  3   Screen Size       0 non-null      float64
#  4   CPU               1274 non-null   object
#  5    Storage          1274 non-null   object
#  6   GPU               1274 non-null   object
#  7   Operating System  1274 non-null   object
#  8   Price             1274 non-null   float64
#  9   Sreen Resolution  1274 non-null   object
#  10  Display Type      393 non-null    object
#  11  Touchscreen       1274 non-null   int32
#  12  CPU_Manufacturer  1274 non-null   object
#  13  GPU_Manufacturer  1274 non-null   object
#  14  Frequency         1274 non-null   object
#  15  RAM(in GB)        1274 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model Name', 'Category', 'Screen Size', 'CPU',
#        ' Storage', 'GPU', 'Operating System', 'Price', 'Sreen Resolution',
#        'Display Type', 'Touchscreen', 'CPU_Manufacturer', 'GPU_Manufacturer',
#        'Frequency', 'RAM(in GB)', 'Weight(in Kg)'],
#       dtype='object')

# %%
df[['Storage1','Storage2']]=df[' Storage'].str.split('+',n=1,expand=True)

# %%
df['Storage1']=df['Storage1'].str.replace('GB','')
df['Storage2']=df['Storage2'].str.replace('GB','')

# %%
df['Storage1']=df['Storage1'].str.replace('TB','000')
df['Storage2']=df['Storage2'].str.replace('TB','000')

# %%
df['Storage1'].value_counts()
# Out:
# Storage1
# 256 SSD              412
# 1000 HDD             216
# 500 HDD              124
# 512 SSD              114
# 128 SSD               96
# 256 SSD               88
# 128 SSD               74
# 32 Flash Storage      36
# 512 SSD               19
# 2000 HDD              16
# 1000 SSD              14
# 64 Flash Storage      13
# 256 Flash Storage      8
# 16 Flash Storage       7
# 1000 Hybrid            7
# 32 SSD                 6
# 1 SSD                  5
# 128 Flash Storage      4
# 16 SSD                 3
# 1000 SSD               2
# 512 Flash Storage      2
# 64 SSD                 1
# 64 Flash Storage       1
# 1000 HDD               1
# 32 HDD                 1
# 128 HDD                1
# 240 SSD                1
# 8 SSD                  1
# 508 Hybrid             1
# Name: count, dtype: int64

# %%
df['Storage2'].value_counts()
# Out:
# Storage2
# 1000 HDD       185
# 2000 HDD        14
# 256 SSD          3
# 500 HDD          2
# 1000 Hybrid      2
# 512 SSD          1
# Name: count, dtype: int64

# %%
df[['Storage1(in GB)','Storage1_Type']]=df['Storage1'].str.extract(r'(\d+)([a-zA-Z\s]+)')

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size                   CPU  \
# 0        Apple  MacBook Pro  Ultrabook          NaN        Intel Core i5
# 1        Apple  Macbook Air  Ultrabook          NaN        Intel Core i5
# 2           HP       250 G6   Notebook          NaN  Intel Core i5 7200U
# 3        Apple  MacBook Pro  Ultrabook          NaN        Intel Core i7
# 4        Apple  MacBook Pro  Ultrabook          NaN        Intel Core i5
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# 2            256GB SSD         Intel HD Graphics 620            No OS
# 3            512GB SSD            AMD Radeon Pro 455            macOS
# 4            256GB SSD  Intel Iris Plus Graphics 650            macOS
#
#          Price Sreen Resolution  ... Touchscreen  CPU_Manufacturer  \
# ...

# %%
df['Storage1(in GB)'].value_counts()
# Out:
# Storage1(in GB)
# 256     508
# 1000    240
# 128     175
# 512     135
# 500     124
# 32       43
# 2000     16
# 64       15
# 16       10
# 1         5
# 240       1
# 8         1
# 508       1
# Name: count, dtype: int64

# %%
df['Storage1_Type'].value_counts()
# Out:
# Storage1_Type
# SSD               631
# HDD               358
# SSD               205
# Flash Storage      70
# Hybrid              8
# Flash Storage       1
# HDD                 1
# Name: count, dtype: int64

# %%
df['Storage1_Type'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Storage1_Type'>

# %%
df['Storage1(in GB)']=df['Storage1(in GB)'].astype(int)

# %%
df[['Storage2(in GB)','Storage2_Type']]=df['Storage2'].str.extract(r'(\d+)([a-zA-Z\s]+)')

# %%
df['Storage2(in GB)'].value_counts(dropna=False)
# Out:
# Storage2(in GB)
# NaN     1067
# 1000     187
# 2000      14
# 256        3
# 500        2
# 512        1
# Name: count, dtype: int64

# %%
df['Storage2_Type'].value_counts(dropna=False)
# Out:
# Storage2_Type
# NaN        1067
#  HDD        201
#  SSD          4
#  Hybrid       2
# Name: count, dtype: int64

# %%
df['Storage2(in GB)']=df['Storage2(in GB)'].fillna(0)

# %%
df['Storage2(in GB)']=df['Storage2(in GB)'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      1274 non-null   object
#  1   Model Name        1274 non-null   object
#  2   Category          1274 non-null   object
#  3   Screen Size       0 non-null      float64
#  4   CPU               1274 non-null   object
#  5    Storage          1274 non-null   object
#  6   GPU               1274 non-null   object
#  7   Operating System  1274 non-null   object
#  8   Price             1274 non-null   float64
#  9   Sreen Resolution  1274 non-null   object
#  10  Display Type      393 non-null    object
#  11  Touchscreen       1274 non-null   int32
#  12  CPU_Manufacturer  1274 non-null   object
#  13  GPU_Manufacturer  1274 non-null   object
#  14  Frequency         1274 non-null   object
#  15  RAM(in GB)        1274 non-null   float64
# ...

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size                   CPU  \
# 0        Apple  MacBook Pro  Ultrabook          NaN        Intel Core i5
# 1        Apple  Macbook Air  Ultrabook          NaN        Intel Core i5
# 2           HP       250 G6   Notebook          NaN  Intel Core i5 7200U
# 3        Apple  MacBook Pro  Ultrabook          NaN        Intel Core i7
# 4        Apple  MacBook Pro  Ultrabook          NaN        Intel Core i5
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# 2            256GB SSD         Intel HD Graphics 620            No OS
# 3            512GB SSD            AMD Radeon Pro 455            macOS
# 4            256GB SSD  Intel Iris Plus Graphics 650            macOS
#
#          Price Sreen Resolution  ... GPU_Manufacturer  Frequency RAM(in GB)  \
# ...

# %%
df.drop([' Storage','Storage1','Storage2'],inplace=True,axis=1)

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model Name', 'Category', 'Screen Size', 'CPU', 'GPU',
#        'Operating System', 'Price', 'Sreen Resolution', 'Display Type',
#        'Touchscreen', 'CPU_Manufacturer', 'GPU_Manufacturer', 'Frequency',
#        'RAM(in GB)', 'Weight(in Kg)', 'Storage1(in GB)', 'Storage1_Type',
#        'Storage2(in GB)', 'Storage2_Type'],
#       dtype='object')

# %%
df['Storage1_Type'].value_counts()
# Out:
# Storage1_Type
# SSD               631
# HDD               358
# SSD               205
# Flash Storage      70
# Hybrid              8
# Flash Storage       1
# HDD                 1
# Name: count, dtype: int64

# %%
df['Storage2_Type'].value_counts()
# Out:
# Storage2_Type
# HDD       201
# SSD         4
# Hybrid      2
# Name: count, dtype: int64

# %%
df['Storage1_Type']=df['Storage1_Type'].str.replace(r' ','',regex=True)

# %%
df['Storage1_Type'].value_counts(dropna=False)
# Out:
# Storage1_Type
# SSD             836
# HDD             359
# FlashStorage     71
# Hybrid            8
# Name: count, dtype: int64

# %%
df['Storage1_Type'].value_counts().plot(kind='bar',color='green')
# Out:
# <Axes: xlabel='Storage1_Type'>

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model Name', 'Category', 'Screen Size', 'CPU', 'GPU',
#        'Operating System', 'Price', 'Sreen Resolution', 'Display Type',
#        'Touchscreen', 'CPU_Manufacturer', 'GPU_Manufacturer', 'Frequency',
#        'RAM(in GB)', 'Weight(in Kg)', 'Storage1(in GB)', 'Storage1_Type',
#        'Storage2(in GB)', 'Storage2_Type'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Manufacturer           0
# Model Name             0
# Category               0
# Screen Size         1274
# CPU                    0
# GPU                    0
# Operating System       0
# Price                  0
# Sreen Resolution       0
# Display Type         881
# Touchscreen            0
# CPU_Manufacturer       0
# GPU_Manufacturer       0
# Frequency              0
# RAM(in GB)             0
# Weight(in Kg)          0
# Storage1(in GB)        0
# Storage1_Type          0
# Storage2(in GB)        0
# Storage2_Type       1067
# dtype: int64

# %%
df['Storage2_Type']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1269    NaN
# 1270    NaN
# 1271    NaN
# 1272    NaN
# 1273    NaN
# Name: Storage2_Type, Length: 1274, dtype: object

# %%
df['Model Name'].unique()
# Out:
# array(['MacBook Pro', 'Macbook Air', '250 G6', 'Aspire 3',
#        'ZenBook UX430UN', 'Swift 3', 'Inspiron 3567', 'MacBook 12"',
#        'IdeaPad 320-15IKB', 'XPS 13', 'Vivobook E200HA',
#        'Legion Y520-15IKBN', '255 G6', 'Inspiron 5379',
#        '15-BS101nv (i7-8550U/8GB/256GB/FHD/W10)', 'MacBook Air',
#        'Inspiron 5570', 'Latitude 5590', 'ProBook 470', 'LapBook 15.6"',
#        'E402WA-GA010T (E2-6110/2GB/32GB/W10)',
#        '17-ak001nv (A6-9220/4GB/500GB/Radeon', 'IdeaPad 120S-14IAP',
#        'Inspiron 5770', 'ProBook 450',
#        'X540UA-DM186 (i3-6006U/4GB/1TB/FHD/Linux)', 'Inspiron 7577',
#        'X542UQ-GO005 (i5-7200U/8GB/1TB/GeForce', 'Aspire A515-51G',
#        'Inspiron 7773', 'IdeaPad 320-15ISK', 'Rog Strix',
#        'X751NV-TY001T (N4200/4GB/1TB/GeForce', 'Yoga Book', 'ProBook 430',
#        'Inspiron 3576', '15-bs002nv (i3-6006U/4GB/128GB/FHD/W10)',
#        'VivoBook Max', 'GS73VR 7RG',
# ...

# %%
df.drop('Storage2_Type',axis=1,inplace=True)

# %%
df['Display Type'].isnull().sum()
# Out:
# 881

# %%
df.shape
# Out:
# (1274, 19)

# %%
#Out of 1274 values 917 are null .So,Drop the column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      1274 non-null   object
#  1   Model Name        1274 non-null   object
#  2   Category          1274 non-null   object
#  3   Screen Size       0 non-null      float64
#  4   CPU               1274 non-null   object
#  5   GPU               1274 non-null   object
#  6   Operating System  1274 non-null   object
#  7   Price             1274 non-null   float64
#  8   Sreen Resolution  1274 non-null   object
#  9   Display Type      393 non-null    object
#  10  Touchscreen       1274 non-null   int32
#  11  CPU_Manufacturer  1274 non-null   object
#  12  GPU_Manufacturer  1274 non-null   object
#  13  Frequency         1274 non-null   object
#  14  RAM(in GB)        1274 non-null   float64
#  15  Weight(in Kg)     1274 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Manufacturer           0
# Model Name             0
# Category               0
# Screen Size         1274
# CPU                    0
# GPU                    0
# Operating System       0
# Price                  0
# Sreen Resolution       0
# Display Type         881
# Touchscreen            0
# CPU_Manufacturer       0
# GPU_Manufacturer       0
# Frequency              0
# RAM(in GB)             0
# Weight(in Kg)          0
# Storage1(in GB)        0
# Storage1_Type          0
# Storage2(in GB)        0
# dtype: int64

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size                   CPU  \
# 0        Apple  MacBook Pro  Ultrabook          NaN        Intel Core i5
# 1        Apple  Macbook Air  Ultrabook          NaN        Intel Core i5
# 2           HP       250 G6   Notebook          NaN  Intel Core i5 7200U
# 3        Apple  MacBook Pro  Ultrabook          NaN        Intel Core i7
# 4        Apple  MacBook Pro  Ultrabook          NaN        Intel Core i5
#
#                             GPU Operating System        Price  \
# 0  Intel Iris Plus Graphics 640            macOS  11912523.48
# 1        Intel HD Graphics 6000            macOS   7993374.48
# 2         Intel HD Graphics 620            No OS   5112900.00
# 3            AMD Radeon Pro 455            macOS  22563005.40
# 4  Intel Iris Plus Graphics 650            macOS  16037611.20
#
#   Sreen Resolution           Display Type  Touchscreen CPU_Manufacturer  \
# 0        2560x1600  IPSPanelRetinaDisplay            0            Intel
# ...

# %%
df.isnull().sum()
# Out:
# Manufacturer           0
# Model Name             0
# Category               0
# Screen Size         1274
# CPU                    0
# GPU                    0
# Operating System       0
# Price                  0
# Sreen Resolution       0
# Display Type         881
# Touchscreen            0
# CPU_Manufacturer       0
# GPU_Manufacturer       0
# Frequency              0
# RAM(in GB)             0
# Weight(in Kg)          0
# Storage1(in GB)        0
# Storage1_Type          0
# Storage2(in GB)        0
# dtype: int64

# %%
df.to_csv('cleaned_laptop_price_data')
